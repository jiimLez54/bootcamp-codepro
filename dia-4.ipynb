# %%
persona={}
print(persona)
nombre_del_sujeto= input('ingrese su nombre')
print  ({'Isabella'})

edad_del_sujeto= input('ingrese su edad')
print({'14', 'Isabella'})

sexo_del_sujeto= input('ingrese su sexo')
print({'femenino', '14','Isabella'})

telefono_del_sujeto= input('ingrese su numero de telefono')
print({'0985742564', 'femenino','14','Isabella'})

email_del_sujeto= input('ingrese su email')
print({'isabella_molinas18@gmail.com','0985742564', 'femenino','14','Isabella'})
