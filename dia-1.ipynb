# %%
nombre = 'jimena'
edad = 18
altura = 1,68
cuidad = 'fernando'
print (nombre)
print (edad)
print (altura)
print (cuidad)
# Out:
# jimena
# 18
# (1, 68)
# fernando

# %%
#valor de variables
cantidad_de_manzanas= 4
cantidad_de_naranjas= 7

cantidad_de_frutas= cantidad_de_manzanas + cantidad_de_naranja
print (cantidad_de_manzanas)
print (cantidad_de_naranjas)
# Out:
# 4
# 5

# %%
nombre= 'fabiola'
apellido= 'britos'
print (nombre+" "+apellido)
print (f"ella es mi compañera {nombre} {apellido}")
# Out:
# fabiola britos
# ella es mi compañera fabiola britos

# %%
total_caramelos= int(input("¿cual es tu cantidad de caramelo?:"))
niños= int(input("¿cuantos niños?:"))

caramelos_por_niños = total_caramelos // niños
print(f"se entregaron{caramelos_por_niños} caramelo")

caramelos_sobrantes = total_caramelos - caramelos_por_niños
print(f"sobraros {caramelos_sobrantes} caramelos")
# Out:
# se entregaron2 caramelo
# sobraros 8 caramelos

# %%
def saludos():
    nombre = input('ingrese su nombre')
    apellido1 = input('ingrese su apellido')
    ciudad = input('ingrese su cuidad')
    print(f'hola mi nombre es {nombre} {apellido1}')
saludos()
saludos()
saludos()
# Out:
# hola mi nombre es max lopez
# hola mi nombre es lucia perez
# hola mi nombre es fabiola britos

# %%
combo_usuario = input('ingrese su pedido')
agregado = input('ingrese su agregado')

def preparar_pedido(combo,agregado):
    print(f'preparando tu combo: {combo} con agregado {agregado}')
    print('pedido saliendo')

preparar_pedido(combo_usuario, agregado)
# Out:
# preparando tu combo: lomito con agregado helado
# pedido saliendo

# %%
calcular_total = int(input("ingrese el valor del producto"))
impuesto = 14000

Starbucks ='chocolate'
def preparar_un_chocolate():
