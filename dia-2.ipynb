# %%
# proceso de desarrollo
edad = int(input('ingrese su edad'))
if edad < 18:
    print("aceso denegado - solo zona de kits 🎈")
elif edad >18 and edad < 21:
    print("Acceso permitido — No puede comprar bebidas alcoholicas 🎟️")
elif edad > 21:
    print("Acceso total — Disfruta el festival 🎉")
# Out:
# Acceso total — Disfruta el festival 🎉

# %%
# pedir al usuario
temperatura_usuario = int(input('ingrese la temperatura'))

# primera condicion
if temperatura_usuario >= -10 and temperatura_usuario <= 13:
    print("Ro'y koko")

if temperatura_usuario >= 14 and temperatura_usuario <= 23:
    print("Refresca'i")

if temperatura_usuario >= 24 and temperatura_usuario <= 28:
    print("Oikoite")
if temperatura_usuario >= 29 and temperatura_usuario <= 45:
    print("Hakurooooo")
else:
    print("Ñamano mba'e!")
# Out:
# Ñamano mba'e!

# %%
# proceso
contraseña = "festival123"
entrada = input("ingrese la contraseña: ")
while entrada != contraseña:
    pint("contraseña incorrecta. Intente de nuevo")
    entrada = input("ingrese la contraseña: ")
print("contraseña correcta  🎉")
# Out:
# contraseña correcta  🎉

# %%
listra_de_frutas =  ['naranja' , 'peras' , 'piñas' , 'kiwi' , 'sandia']
lista_bool = [True, False , True]
lista_de_numeros = [1.0 , 3 , 18 , 4.5]

# %%
# 5 elementos
lista = ["hoodie" , "accesorios" , "remera" , "vans"]

# Agregar un elemento al finalde la lista
lista.append("gorra")

#modificar el segundo elementos
lista[1] = "pantalones cargo"

# Eliminar el tercer elemento
lista.pop(2)

#mostrar la lista final
print(lista)
# Out:
# ['hoodie', 'pantalones cargo', 'vans', 'gorra']

# %%
# ejemplo 1
for i in range(10):
    i = i*2
    print(f'el valor de i es: {i}')

#ejemplo 2
# Out:
# el valor de i es: 0
# el valor de i es: 2
# el valor de i es: 4
# el valor de i es: 6
# el valor de i es: 8
# el valor de i es: 10
# el valor de i es: 12
# el valor de i es: 14
# el valor de i es: 16
# el valor de i es: 18

# %%
lista_marca = ["Lenovo" , "Dell" , "Samsung" , "Apple" , "Acer"]
for i in lista_marca:
    if len(i) >= 6:
        print(i)
# Out:
# Lenovo
# Samsung

# %%
sujeto = input("ingrese una letra")
for letra in sujeto:
    if letra == "o":
        print("se econtro una letra o")
# Out:
# se econtro una letra o
